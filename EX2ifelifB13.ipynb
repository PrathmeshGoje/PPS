# %% [markdown]
# 1. To find the largest of three numbers.

# %%
num1 = int(input("Enter first number: "))
num2 = int(input("Enter second number: "))
num3 = int(input("Enter third number: "))
 
if (num1 > num2) and (num1 > num3):
   largest = num1
elif (num2 > num1) and (num2 > num3):
   largest = num2
else:
   largest = num3
 
print("The largest number is",largest)
# Out:
# Enter first number: 5
# Enter second number: 6
# Enter third number: 4
# The largest number is 6

# %% [markdown]
# 2. To find the smallest of five numbers.

# %%
lst = []
 
num = int(input('How many numbers: '))
 
for n in range(num):
    numbers = int(input('Enter number '))
    lst.append(numbers)
     
print("Minimum element in the list is :", min(lst))
# Out:
# How many numbers: 5
# Enter number 9
# Enter number 8
# Enter number 7
# Enter number 5
# Enter number 6
# Minimum element in the list is : 5

# %% [markdown]
# 3. To print the grade of students based on marks secured by him.

# %%
print("Enter Marks Obtained By Student: ")
marks = int(input())
if marks>= 95:
    print("Outstanding")
elif marks>=85 and marks<95:
    print("A+ Grade")
elif marks>=75 and marks<85:
    print("Distinction")
elif marks>75 and marks<=60:
    print("A Grade")
elif marks>=59 and marks<40:
    print("B Grade")
elif marks==40:
    print("Pass")
elif marks<=40:
    print("Fail")
# Out:
# Enter Marks Obtained By Student:
# 97
# Outstanding

# %% [markdown]
# 4. To print Eligibility of voting of a person based on his age. Ask the user to enter his age.

# %%
age= int(input("Enter your Age: "))
if age>=18:
  print("Your Are Eligible.")
else:
  print("Your Are Not Eligible.")
# Out:
# Enter your Age: 21
# Your Are Eligible.

# %% [markdown]
# 5. To print Eligibility for medical/Engineering based on marks in PCM.

# %%
P= int(input("Physics Marks: "))
C= int(input("Chemistry Marks: "))
M= int(input("Maths Marks: "))
T=P+C+M
if (P>=55) and (C >=50) and (M>=65) and (T>=140):
  print("Medical")
else:
   print("Engineering")
# Out:
# Physics Marks: 50
# Chemistry Marks: 50
# Maths Marks: 60
# Engineering

# %% [markdown]
# 6.To print type of weather based on the temperature taken from consol.

# %%
print("Enter The Temprature: ")
T= int(input())
if T<= 0:
    print("Freezing")
elif T>0 and T<10:
    print("Very Cold")
elif T>=10 and T<20:
    print("Cold")
elif T>=20 and T<30:
    print("Normal")
elif T>=30 and T<40:
    print("Hot")
elif T>=40:
    print("Very Hot")
# Out:
# Enter The Temprature:
# 28
# Normal

# %% [markdown]
# 7. To compute the roots of a quadratic equation and print the types of the roots as the outcome
# whether the types of the root is positive or negative.

# %%
from math import sqrt
print("Quadratic function : (a * x^2) + b*x + c")
a = float(input("a: "))
b = float(input("b: "))
c = float(input("c: "))

r = b**2 - 4*a*c

if r > 0:
    num_roots = 2
    x1 = (((-b) + sqrt(r))/(2*a))     
    x2 = (((-b) - sqrt(r))/(2*a))
    print("There are 2 roots: %f and %f" % (x1, x2))
elif r == 0:
    num_roots = 1
    x = (-b) / 2*a
    print("There is one root: ", x)
# Out:
# Quadratic function : (a * x^2) + b*x + c
# a: 2
# b: 5
# c: 3
# There are 2 roots: -1.000000 and -1.500000

# %% [markdown]
# 8. Ask the user to enter the x, y co-ordinates of a point and determine whether the point is in
# I/II/III/IV quadrant.

# %%
a = int(input("X="))
b = int(input("Y="))
if(a > 0 and b > 0):
	print("Ist Quadrant")
elif(a < 0 and b > 0):
	print("IInd Quadrant")
elif(a < 0 and b < 0):
	print("IIIrd Quadrant")
elif(a > 0 and b < 0):
	print("IVth Quadrant")
else:
	print("Origin")
# Out:
# X=5
# Y=5
# Ist Quadrant

# %% [markdown]
# 9. To check whether the alphabet entered by the user is a vowel or a consonant.

# %%
l = input("Input a letter of the alphabet: ")

if l in ('a', 'e', 'i', 'o', 'u'):
	print("%s is a vowel." % l)
else:
	print("%s is a consonant." % l)
# Out:
# Input a letter of the alphabet: e
# e is a vowel.

# %% [markdown]
# 10. To print the electricity bill of a consumer based on the following data:
# Units consumed Charge/Unit

# %%
units=int(input("Units consumed:"))
if(units<83):
    payAmount=100
    print("Total Bill=%.2f"%payAmount)   
elif(units>83 and units<=199):
    payAmount=units*1.20
    print("Total Bill=%.2f"%payAmount)
elif(units>=200 and units<=399):
    payAmount=(199*1.20)+(units-199)*1.50
    print("Total Bill=%.2f"%payAmount)
elif(units>=400 and units<=600):
    payAmount=(199*1.20)+(399-199)*1.50+(units-200)*1.80
    Surcharge=units*15/100
    print("Fine=%.2f" %Surcharge)
    Total=Surcharge+payAmount
    print("Total Bill=%.2f" %Total)
elif(units>600):
    payAmount=(199*1.20)+(399-199)*1.50+(600-400)*1.80+(units-300)*2
    Surcharge=units*15/100
    print("Fine=%.2f" %Surcharge)
    Total=Surcharge+payAmount
    print("Total Bill=%.2f" %Total)
else:
    print("invalid input")
# Out:
# Units consumed:600
# Fine=90.00
# Total Bill=1348.80
